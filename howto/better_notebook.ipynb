# %% [markdown]
# # Better notebook interactions

# %%
import eradiate
eradiate.set_mode("ckd")

# %%
# Basic behaviour: looks bad
exp = eradiate.experiments.OneDimExperiment(
    measures={
        "type": "mdistant",
        "construct": "from_viewing_angles",
        "zeniths": [-30, 0, 30],
        "azimuths": 0,
        "spectral_cfg": {
            "bin_set": "10nm",
            "bins": ["550"],
        },
    }
)
exp

# %%
eradiate.run(exp)

# %%
# %load_ext eradiate

# %%
eradiate.experiments.OneDimExperiment()

# %%
eradiate.run(exp)

# %%
eradiate.config.progress = "SPECTRAL_LOOP"

# %%
eradiate.run(exp)
